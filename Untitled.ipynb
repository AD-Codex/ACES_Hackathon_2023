# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import requests
from urllib.request import urlopen
import sys

# %%
# # cap = cv2.VideoCapture('rtsp://user:password@192.168.150.162:6677')

# RTSP_URL = 'rtsp://user:pass@192.168.150.162:6677/h264Preview_01_main'

# os.environ['OPENCV_FFMPEG_CAPTURE_OPTIONS'] = 'rtsp_transport;udp'

cap = cv2.VideoCapture("http://192.168.150.210:4747/video")

while cap.isOpened():

    ret, frame = cap.read()

    cv2.imshow('openCV Feed', frame)
    if  cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# QObject::moveToThread: Current thread (0x24c8580) is not the object's thread (0x3348d80).
# Cannot move to target thread (0x24c8580)
#
# ...

# %%
host = "192.168.150.210:4747"
# if len(sys.argv)>1:
#     host = sys.argv[1]

hoststr = 'http://' + host + '/video'
print ('Streaming ' + hoststr)

stream=urlopen(hoststr)

bytes=''
while True:
    bytes+=stream.read(1024)
    a = bytes.find('\xff\xd8')
    b = bytes.find('\xff\xd9')
    if a!=-1 and b!=-1:
        jpg = bytes[a:b+2]
        bytes= bytes[b+2:]
        i = cv2.imdecode(np.fromstring(jpg, dtype=np.uint8),cv2.CV_LOAD_IMAGE_COLOR)
        cv2.imshow(hoststr,i)
        if cv2.waitKey(1) ==27:
            exit(0)
# Out:
# Streaming http://192.168.150.210:4747/video
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 12
#      10 bytes=''
#      11 while True:
# ---> 12     bytes+=stream.read(1024)
#      13     a = bytes.find('\xff\xd8')
#      14     b = bytes.find('\xff\xd9')
#
# TypeError: can only concatenate str (not "bytes") to str

# %%
cap.release()
cv2.destroyAllWindows()
